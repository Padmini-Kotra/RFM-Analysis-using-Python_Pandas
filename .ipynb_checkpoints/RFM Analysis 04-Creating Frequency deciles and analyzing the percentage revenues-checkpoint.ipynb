# %%
import pandas as pd
import numpy as np

# %%
df_RFM=pd.read_csv("RFM_retail.csv")
df_RFM.head()
# Out:
#    Customer ID           Duration  Freq    Tot_Rev      Avg_Rev
# 0        12346  347 days 13:43:00    48  155177.60  3232.866667
# 1        12347   61 days 11:35:00   242    5408.50    22.349174
# 2        12348   97 days 10:47:00    51    2019.40    39.596078
# 3        12349   40 days 14:09:00   180    4452.84    24.738000
# 4        12350  332 days 07:59:00    17     334.40    19.670588

# %%
#Converting Duration to timedelta data type to be able to make deciles
df_RFM.Duration=pd.to_timedelta(df_RFM.Duration)
df_RFM.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5924 entries, 0 to 5923
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Customer ID  5924 non-null   int64
#  1   Duration     5924 non-null   timedelta64[ns]
#  2   Freq         5924 non-null   int64
#  3   Tot_Rev      5924 non-null   float64
#  4   Avg_Rev      5924 non-null   float64
# dtypes: float64(2), int64(2), timedelta64[ns](1)
# memory usage: 231.5 KB

# %% [markdown]
# ### Task 3:

# %%
# Creating frequency deciles using pd.qcut
df_RFM['Frequency_Deciles'] = pd.qcut(df_RFM['Freq'], q=10)
df_RFM.head()
# Out:
#    Customer ID          Duration  Freq    Tot_Rev      Avg_Rev  \
# 0        12346 347 days 13:43:00    48  155177.60  3232.866667
# 1        12347  61 days 11:35:00   242    5408.50    22.349174
# 2        12348  97 days 10:47:00    51    2019.40    39.596078
# 3        12349  40 days 14:09:00   180    4452.84    24.738000
# 4        12350 332 days 07:59:00    17     334.40    19.670588
#
#   Frequency_Deciles
# 0      (37.0, 53.0]
# 1    (180.0, 319.7]
# 2      (37.0, 53.0]
# 3    (114.0, 180.0]
# 4      (16.0, 25.0]

# %%
# Calculating total revenue for each frequency decile
df_freq_rev = df_RFM.groupby('Frequency_Deciles')['Tot_Rev'].sum().reset_index()
df_freq_rev.head()
# Out:
#   Frequency_Deciles     Tot_Rev
# 0      (0.999, 8.0]  404327.920
# 1       (8.0, 16.0]  323577.170
# 2      (16.0, 25.0]  290291.051
# 3      (25.0, 37.0]  435255.361
# 4      (37.0, 53.0]  846488.273

# %%
# Calculating cumulative total revenue
df_freq_rev['cumsum'] = df_freq_rev['Tot_Rev'].cumsum()
df_freq_rev.head()
# Out:
#   Frequency_Deciles     Tot_Rev       cumsum
# 0      (0.999, 8.0]  404327.920   404327.920
# 1       (8.0, 16.0]  323577.170   727905.090
# 2      (16.0, 25.0]  290291.051  1018196.141
# 3      (25.0, 37.0]  435255.361  1453451.502
# 4      (37.0, 53.0]  846488.273  2299939.775

# %%
# Calculating the total revenue across all deciles
df_freq_rev['Total'] =df_freq_rev['Tot_Rev'].sum()
df_freq_rev.head()
# Out:
#   Frequency_Deciles     Tot_Rev       cumsum         Total
# 0      (0.999, 8.0]  404327.920   404327.920  1.824577e+07
# 1       (8.0, 16.0]  323577.170   727905.090  1.824577e+07
# 2      (16.0, 25.0]  290291.051  1018196.141  1.824577e+07
# 3      (25.0, 37.0]  435255.361  1453451.502  1.824577e+07
# 4      (37.0, 53.0]  846488.273  2299939.775  1.824577e+07

# %%
# Calculating the percentage of cumulative revenue each decile represents
df_freq_rev['Perc_Tot_Rev'] = (df_freq_rev['cumsum'] / df_freq_rev['Total'][0])
df_freq_rev
# Out:
#   Frequency_Deciles      Tot_Rev        cumsum         Total  Perc_Tot_Rev
# 0      (0.999, 8.0]   404327.920  4.043279e+05  1.824577e+07      0.022160
# 1       (8.0, 16.0]   323577.170  7.279051e+05  1.824577e+07      0.039894
# 2      (16.0, 25.0]   290291.051  1.018196e+06  1.824577e+07      0.055805
# 3      (25.0, 37.0]   435255.361  1.453452e+06  1.824577e+07      0.079660
# 4      (37.0, 53.0]   846488.273  2.299940e+06  1.824577e+07      0.126053
# 5      (53.0, 76.0]   840613.700  3.140553e+06  1.824577e+07      0.172125
# 6     (76.0, 114.0]  1134640.972  4.275194e+06  1.824577e+07      0.234312
# 7    (114.0, 180.0]  1763356.203  6.038551e+06  1.824577e+07      0.330956
# 8    (180.0, 319.7]  3008457.952  9.047009e+06  1.824577e+07      0.495842
# 9  (319.7, 12780.0]  9198758.276  1.824577e+07  1.824577e+07      1.000000

# %%
# Finding the range of frequency where ~65% of the revenue is realized
df_freq_rev[(df_freq_rev['Perc_Tot_Rev']*100 >=45) & (df_freq_rev['Perc_Tot_Rev']*100<=85)]
# Out:
#   Frequency_Deciles      Tot_Rev       cumsum         Total  Perc_Tot_Rev
# 8    (180.0, 319.7]  3008457.952  9047008.602  1.824577e+07      0.495842

# %% [markdown]
# #### In one frequency decile the percentage of revenue realized is a little close to 65. But in fact, there is no decile in which the revenue percentage is very close to 65%. The closest is 49.5%
